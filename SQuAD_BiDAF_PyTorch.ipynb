# %% [markdown]
# <a href="https://colab.research.google.com/github/vrushaligirkar/NLP-Project-QA-system/blob/master/SQuAD_BiDAF_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import sys
import argparse
import json
import os
import copy
from datetime import datetime
import nltk
nltk.download('punkt')

import torch
print(torch.__version__)
import torchtext
from torchtext import data
print(torchtext.__version__)
from torchtext import datasets
from torchtext.vocab import GloVe
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

from google.colab import drive
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 1.4.0
# 0.3.1

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#Load pickled GTSRB data
training_file = '/content/gdrive/My Drive/Colab Notebooks/data/train-v2.0.json'
dev_file = '/content/gdrive/My Drive/Colab Notebooks/data/dev-v2.0.json'

# %%
args = {}
args['--char-dim'] = 8
args['--char-channel-width'] = 5
args['--char-channel-size'] = 100
args['--context-threshold'] = 400
args['--dev-batch-size'] = 100
args['--dev-file'] = dev_file
args['--dropout'] = 0.2
args['--epoch'] = 12
args['--exp-decay-rate'] = 0.999
args['--gpu'] = 0 
args['--hidden-size'] = 100
args['--learning-rate'] = 0.5
args['--print-freq'] = 250
args['--train-batch-size'] = 60
args['--train-file'] = training_file
args['--word-dim'] = 100

# %%
def word_tokenize(tokens):
    return [token.replace("''", '"').replace("``", '"') for token in nltk.word_tokenize(tokens)]

# %%
class SQuAD():
    def __init__(self, args):
        path = '/content/gdrive/My Drive/Colab Notebooks/data'
        dataset_path = path + '/torchtext/'
        train_examples_path = dataset_path + 'train_examples.pt'
        dev_examples_path = dataset_path + 'dev_examples.pt'

        print("preprocessing data files...")
        self.preprocess_file(args['--train-file'])
        self.preprocess_file(args['--dev-file'])
        #if not os.path.exists('{}/{}'.format(path, args['--train-file'])):
        #    self.preprocess_file('{}/{}'.format(path, args['--train-file']))
        #if not os.path.exists('{}/{}l'.format(path, args['--dev-file'])):
        #    self.preprocess_file('{}/{}'.format(path, args['--dev-file']))
        #if nor os.path.exists(arg)

        self.RAW = data.RawField()
        # explicit declaration for torchtext compatibility
        self.RAW.is_target = False
        self.CHAR_NESTING = data.Field(batch_first=True, tokenize=list, lower=True)
        self.CHAR = data.NestedField(self.CHAR_NESTING, tokenize=word_tokenize)
        self.WORD = data.Field(batch_first=True, tokenize=word_tokenize, lower=True, include_lengths=True)
        self.LABEL = data.Field(sequential=False, unk_token=None, use_vocab=False)

        dict_fields = {'id': ('id', self.RAW),
                       's_idx': ('s_idx', self.LABEL),
                       'e_idx': ('e_idx', self.LABEL),
                       'context': [('c_word', self.WORD), ('c_char', self.CHAR)],
                       'question': [('q_word', self.WORD), ('q_char', self.CHAR)]}

        list_fields = [('id', self.RAW), ('s_idx', self.LABEL), ('e_idx', self.LABEL),
                       ('c_word', self.WORD), ('c_char', self.CHAR),
                       ('q_word', self.WORD), ('q_char', self.CHAR)]

        if os.path.exists(dataset_path):
            print("loading splits...")
            train_examples = torch.load(train_examples_path)
            dev_examples = torch.load(dev_examples_path)

            self.train = data.Dataset(examples=train_examples, fields=list_fields)
            self.dev = data.Dataset(examples=dev_examples, fields=list_fields)
        else:
            print("building splits...")
            self.train, self.dev = data.TabularDataset.splits(
                path=path,
                train='{}l'.format(args['--train-file']),
                validation='{}l'.format(args['--dev-file']),
                format='json',
                fields=dict_fields)

            os.makedirs(dataset_path)
            torch.save(self.train.examples, train_examples_path)
            torch.save(self.dev.examples, dev_examples_path)

        #cut too long context in the training set for efficiency.
        if args['--context-threshold'] > 0:
            self.train.examples = [e for e in self.train.examples if len(e.c_word) <= args['--context-threshold']]

        print("building vocab...")
        self.CHAR.build_vocab(self.train, self.dev)
        self.WORD.build_vocab(self.train, self.dev, vectors=GloVe(name='6B', dim=args['--word-dim']))

        print("building iterators...")
        device = torch.device("cuda:{}".format(args['--gpu']) if torch.cuda.is_available() else "cpu")
        self.train_iter = data.BucketIterator(
            self.train,
            batch_size=args['--train-batch-size'],
            device=device,
            repeat=True,
            shuffle=True,
            sort_key=lambda x: len(x.c_word)
        )

        self.dev_iter = data.BucketIterator(
            self.dev,
            batch_size=args['--dev-batch-size'],
            device=device,
            repeat=False,
            sort_key=lambda x: len(x.c_word)
        )

        # self.train_iter, self.dev_iter = \
        #    data.BucketIterator.splits((self.train, self.dev),
        #                               batch_sizes=[args.train_batch_size, args.dev_batch_size],
        #                               device=device,
        #                               sort_key=lambda x: len(x.c_word))

    def preprocess_file(self, path):
        dump = []
        abnormals = [' ', '\n', '\u3000', '\u202f', '\u2009']

        with open(path, 'r', encoding='utf-8') as f:
            data = json.load(f)
            data = data['data']

            for article in data:
                for paragraph in article['paragraphs']:
                    context = paragraph['context']
                    tokens = word_tokenize(context)
                    for qa in paragraph['qas']:
                        id = qa['id']
                        question = qa['question']
                        for ans in qa['answers']:
                            answer = ans['text']
                            s_idx = ans['answer_start']
                            e_idx = s_idx + len(answer)

                            l = 0
                            s_found = False
                            for i, t in enumerate(tokens):
                                while l < len(context):
                                    if context[l] in abnormals:
                                        l += 1
                                    else:
                                        break
                                # exceptional cases
                                if t[0] == '"' and context[l:l + 2] == '\'\'':
                                    t = '\'\'' + t[1:]
                                elif t == '"' and context[l:l + 2] == '\'\'':
                                    t = '\'\''

                                l += len(t)
                                if l > s_idx and s_found == False:
                                    s_idx = i
                                    s_found = True
                                if l >= e_idx:
                                    e_idx = i
                                    break

                            dump.append(dict([('id', id),
                                              ('context', context),
                                              ('question', question),
                                              ('answer', answer),
                                              ('s_idx', s_idx),
                                              ('e_idx', e_idx)]))

        with open('{}l'.format(path), 'w', encoding='utf-8') as f:
            for line in dump:
                json.dump(line, f)
                print('', file=f)

# %%
print('loading SQuAD data...')
processed_data = SQuAD(args)
# Out:
# loading SQuAD data...
# preprocessing data files...
# loading splits...
# building vocab...
# .vector_cache/glove.6B.zip: 862MB [06:31, 2.20MB/s]
# 100%|█████████▉| 399068/400000 [00:15<00:00, 25167.16it/s]
# building iterators...

# %%
args['char_vocab_size'] = len(processed_data.CHAR.vocab)
args['word_vocab_size'] = len(processed_data.WORD.vocab)
args['dataset_file'] = args['--dev-file']
#args['prediction_file'] = f'prediction{args['--gpu']}.out'
args['prediction_file'] = 'prediction0.out'
args['model_time'] = datetime.now().strftime('%H:%M:%S')
print('data loading complete')
# Out:
# data loading complete

# %%
#Utils
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, batch_first=False, num_layers=1, bidirectional=False, dropout=0.2):
        super(LSTM, self).__init__()

        self.rnn = nn.LSTM(input_size=input_size,
                           hidden_size=hidden_size,
                           num_layers=num_layers,
                           bidirectional=bidirectional,
                           batch_first=batch_first)
        self.reset_params()
        self.dropout = nn.Dropout(p=dropout)

    def reset_params(self):
        for i in range(self.rnn.num_layers):
            nn.init.orthogonal_(getattr(self.rnn, f'weight_hh_l{i}'))
            nn.init.kaiming_normal_(getattr(self.rnn, f'weight_ih_l{i}'))
            nn.init.constant_(getattr(self.rnn, f'bias_hh_l{i}'), val=0)
            nn.init.constant_(getattr(self.rnn, f'bias_ih_l{i}'), val=0)
            getattr(self.rnn, f'bias_hh_l{i}').chunk(4)[1].fill_(1)

            if self.rnn.bidirectional:
                nn.init.orthogonal_(getattr(self.rnn, f'weight_hh_l{i}_reverse'))
                nn.init.kaiming_normal_(getattr(self.rnn, f'weight_ih_l{i}_reverse'))
                nn.init.constant_(getattr(self.rnn, f'bias_hh_l{i}_reverse'), val=0)
                nn.init.constant_(getattr(self.rnn, f'bias_ih_l{i}_reverse'), val=0)
                getattr(self.rnn, f'bias_hh_l{i}_reverse').chunk(4)[1].fill_(1)

    def forward(self, x):
        x, x_len = x
        x = self.dropout(x)

        x_len_sorted, x_idx = torch.sort(x_len, descending=True)
        x_sorted = x.index_select(dim=0, index=x_idx)
        _, x_ori_idx = torch.sort(x_idx)

        x_packed = nn.utils.rnn.pack_padded_sequence(x_sorted, x_len_sorted, batch_first=True)
        x_packed, (h, c) = self.rnn(x_packed)

        x = nn.utils.rnn.pad_packed_sequence(x_packed, batch_first=True)[0]
        x = x.index_select(dim=0, index=x_ori_idx)
        h = h.permute(1, 0, 2).contiguous().view(-1, h.size(0) * h.size(2)).squeeze()
        h = h.index_select(dim=0, index=x_ori_idx)

        return x, h


class Linear(nn.Module):
    def __init__(self, in_features, out_features, dropout=0.0):
        super(Linear, self).__init__()

        self.linear = nn.Linear(in_features=in_features, out_features=out_features)
        if dropout > 0:
            self.dropout = nn.Dropout(p=dropout)
        self.reset_params()

    def reset_params(self):
        nn.init.kaiming_normal_(self.linear.weight)
        nn.init.constant_(self.linear.bias, 0)

    def forward(self, x):
        if hasattr(self, 'dropout'):
            x = self.dropout(x)
        x = self.linear(x)
        return x

# %%
class BiDAF(nn.Module):
    def __init__(self, args, pretrained):
        super(BiDAF, self).__init__()
        self.args = args

        # 1. Character Embedding Layer
        self.char_emb = nn.Embedding(args['char_vocab_size'], args['--char-dim'], padding_idx=1)
        nn.init.uniform_(self.char_emb.weight, -0.001, 0.001)

        self.char_conv = nn.Sequential(
            nn.Conv2d(1, args['--char-channel-size'], (args['--char-dim'], args['--char-channel-width'])),
            nn.ReLU()
            )

        # 2. Word Embedding Layer
        # initialize word embedding with GloVe
        self.word_emb = nn.Embedding.from_pretrained(pretrained, freeze=True)

        # highway network
        assert self.args['--hidden-size'] * 2 == (self.args['--char-channel-size'] + args['--word-dim'])
        for i in range(2):
            setattr(self, 'highway_linear{}'.format(i),
                    nn.Sequential(Linear(args['--hidden-size'] * 2, args['--hidden-size'] * 2),
                                  nn.ReLU()))
            setattr(self, 'highway_gate{}'.format(i),
                    nn.Sequential(Linear(args['--hidden-size'] * 2, args['--hidden-size'] * 2),
                                  nn.Sigmoid()))

        # 3. Contextual Embedding Layer
        self.context_LSTM = LSTM(input_size=args['--hidden-size'] * 2,
                                 hidden_size=args['--hidden-size'],
                                 bidirectional=True,
                                 batch_first=True,
                                 dropout=args['--dropout'])

        # 4. Attention Flow Layer
        self.att_weight_c = Linear(args['--hidden-size'] * 2, 1)
        self.att_weight_q = Linear(args['--hidden-size'] * 2, 1)
        self.att_weight_cq = Linear(args['--hidden-size'] * 2, 1)

        # 5. Modeling Layer
        self.modeling_LSTM1 = LSTM(input_size=args['--hidden-size'] * 8,
                                   hidden_size=args['--hidden-size'],
                                   bidirectional=True,
                                   batch_first=True,
                                   dropout=args['--dropout'])

        self.modeling_LSTM2 = LSTM(input_size=args['--hidden-size'] * 2,
                                   hidden_size=args['--hidden-size'],
                                   bidirectional=True,
                                   batch_first=True,
                                   dropout=args['--dropout'])

        # 6. Output Layer
        self.p1_weight_g = Linear(args['--hidden-size'] * 8, 1, dropout=args['--dropout'])
        self.p1_weight_m = Linear(args['--hidden-size'] * 2, 1, dropout=args['--dropout'])
        self.p2_weight_g = Linear(args['--hidden-size'] * 8, 1, dropout=args['--dropout'])
        self.p2_weight_m = Linear(args['--hidden-size'] * 2, 1, dropout=args['--dropout'])

        self.output_LSTM = LSTM(input_size=args['--hidden-size'] * 2,
                                hidden_size=args['--hidden-size'],
                                bidirectional=True,
                                batch_first=True,
                                dropout=args['--dropout'])

        self.dropout = nn.Dropout(p=args['--dropout'])

    def forward(self, batch):
        # TODO: More memory-efficient architecture
        def char_emb_layer(x):
            """
            :param x: (batch, seq_len, word_len)
            :return: (batch, seq_len, char_channel_size)
            """
            batch_size = x.size(0)
            # (batch, seq_len, word_len, char_dim)
            x = self.dropout(self.char_emb(x))
            # (batch， seq_len, char_dim, word_len)
            x = x.transpose(2, 3)
            # (batch * seq_len, 1, char_dim, word_len)
            x = x.view(-1, self.args['--char-dim'], x.size(3)).unsqueeze(1)
            # (batch * seq_len, char_channel_size, 1, conv_len) -> (batch * seq_len, char_channel_size, conv_len)
            x = self.char_conv(x).squeeze()
            # (batch * seq_len, char_channel_size, 1) -> (batch * seq_len, char_channel_size)
            x = F.max_pool1d(x, x.size(2)).squeeze()
            # (batch, seq_len, char_channel_size)
            x = x.view(batch_size, -1, self.args['--char-channel-size'])

            return x

        def highway_network(x1, x2):
            """
            :param x1: (batch, seq_len, char_channel_size)
            :param x2: (batch, seq_len, word_dim)
            :return: (batch, seq_len, hidden_size * 2)
            """
            # (batch, seq_len, char_channel_size + word_dim)
            x = torch.cat([x1, x2], dim=-1)
            for i in range(2):
                h = getattr(self, 'highway_linear{}'.format(i))(x)
                g = getattr(self, 'highway_gate{}'.format(i))(x)
                x = g * h + (1 - g) * x
            # (batch, seq_len, hidden_size * 2)
            return x

        def att_flow_layer(c, q):
            """
            :param c: (batch, c_len, hidden_size * 2)
            :param q: (batch, q_len, hidden_size * 2)
            :return: (batch, c_len, q_len)
            """
            c_len = c.size(1)
            q_len = q.size(1)

            # (batch, c_len, q_len, hidden_size * 2)
            #c_tiled = c.unsqueeze(2).expand(-1, -1, q_len, -1)
            # (batch, c_len, q_len, hidden_size * 2)
            #q_tiled = q.unsqueeze(1).expand(-1, c_len, -1, -1)
            # (batch, c_len, q_len, hidden_size * 2)
            #cq_tiled = c_tiled * q_tiled
            #cq_tiled = c.unsqueeze(2).expand(-1, -1, q_len, -1) * q.unsqueeze(1).expand(-1, c_len, -1, -1)

            cq = []
            for i in range(q_len):
                #(batch, 1, hidden_size * 2)
                qi = q.select(1, i).unsqueeze(1)
                #(batch, c_len, 1)
                ci = self.att_weight_cq(c * qi).squeeze()
                cq.append(ci)
            # (batch, c_len, q_len)
            cq = torch.stack(cq, dim=-1)

            # (batch, c_len, q_len)
            s = self.att_weight_c(c).expand(-1, -1, q_len) + \
                self.att_weight_q(q).permute(0, 2, 1).expand(-1, c_len, -1) + \
                cq

            # (batch, c_len, q_len)
            a = F.softmax(s, dim=2)
            # (batch, c_len, q_len) * (batch, q_len, hidden_size * 2) -> (batch, c_len, hidden_size * 2)
            c2q_att = torch.bmm(a, q)
            # (batch, 1, c_len)
            b = F.softmax(torch.max(s, dim=2)[0], dim=1).unsqueeze(1)
            # (batch, 1, c_len) * (batch, c_len, hidden_size * 2) -> (batch, hidden_size * 2)
            q2c_att = torch.bmm(b, c).squeeze()
            # (batch, c_len, hidden_size * 2) (tiled)
            q2c_att = q2c_att.unsqueeze(1).expand(-1, c_len, -1)
            # q2c_att = torch.stack([q2c_att] * c_len, dim=1)

            # (batch, c_len, hidden_size * 8)
            x = torch.cat([c, c2q_att, c * c2q_att, c * q2c_att], dim=-1)
            return x

        def output_layer(g, m, l):
            """
            :param g: (batch, c_len, hidden_size * 8)
            :param m: (batch, c_len ,hidden_size * 2)
            :return: p1: (batch, c_len), p2: (batch, c_len)
            """
            # (batch, c_len)
            p1 = (self.p1_weight_g(g) + self.p1_weight_m(m)).squeeze()
            # (batch, c_len, hidden_size * 2)
            m2 = self.output_LSTM((m, l))[0]
            # (batch, c_len)
            p2 = (self.p2_weight_g(g) + self.p2_weight_m(m2)).squeeze()

            return p1, p2

        # 1. Character Embedding Layer
        c_char = char_emb_layer(batch.c_char)
        q_char = char_emb_layer(batch.q_char)
        # 2. Word Embedding Layer
        c_word = self.word_emb(batch.c_word[0])
        q_word = self.word_emb(batch.q_word[0])
        c_lens = batch.c_word[1]
        q_lens = batch.q_word[1]

        # Highway network
        c = highway_network(c_char, c_word)
        q = highway_network(q_char, q_word)
        # 3. Contextual Embedding Layer
        c = self.context_LSTM((c, c_lens))[0]
        q = self.context_LSTM((q, q_lens))[0]
        # 4. Attention Flow Layer
        g = att_flow_layer(c, q)
        # 5. Modeling Layer
        m = self.modeling_LSTM2((self.modeling_LSTM1((g, c_lens))[0], c_lens))[0]
        # 6. Output Layer
        p1, p2 = output_layer(g, m, c_lens)

        # (batch, c_len), (batch, c_len)
        return p1, p2

# %%
class EMA():
    def __init__(self, mu):
        self.mu = mu
        self.shadow = {}

    def register(self, name, val):
        self.shadow[name] = val.clone()

    def get(self, name):
        return self.shadow[name]

    def update(self, name, x):
        assert name in self.shadow
        new_average = (1.0 - self.mu) * x + self.mu * self.shadow[name]
        self.shadow[name] = new_average.clone()

# %%
def train(args, data):
    device = torch.device(f"cuda:{args['--gpu']}" if torch.cuda.is_available() else "cpu")
    model = BiDAF(args, data.WORD.vocab.vectors).to(device)

    ema = EMA(args['--exp-decay-rate'])
    for name, param in model.named_parameters():
        if param.requires_grad:
            ema.register(name, param.data)
    parameters = filter(lambda p: p.requires_grad, model.parameters())
    optimizer = optim.Adadelta(parameters, lr=args['--learning-rate'])
    criterion = nn.CrossEntropyLoss()

    writer = SummaryWriter(log_dir='runs/' + args['model_time'])

    model.train()
    loss, last_epoch = 0, -1
    max_dev_exact, max_dev_f1 = -1, -1

    iterator = data.train_iter
    for i, batch in enumerate(iterator):
        present_epoch = int(iterator.epoch)
        if present_epoch == args['--epoch']:
            break
        if present_epoch > last_epoch:
            print('epoch:', present_epoch + 1)
        last_epoch = present_epoch

        p1, p2 = model(batch)

        optimizer.zero_grad()
        batch_loss = criterion(p1, batch.s_idx) + criterion(p2, batch.e_idx)
        loss += batch_loss.item()
        batch_loss.backward()
        optimizer.step()

        for name, param in model.named_parameters():
            if param.requires_grad:
                ema.update(name, param.data)

        if (i + 1) % args['--print-freq'] == 0:
            dev_loss, dev_exact, dev_f1 = test(model, ema, args, data)
            c = (i + 1) // args['--print-freq']

            writer.add_scalar('loss/train', loss, c)
            writer.add_scalar('loss/dev', dev_loss, c)
            writer.add_scalar('exact_match/dev', dev_exact, c)
            writer.add_scalar('f1/dev', dev_f1, c)
            print(f'train loss: {loss:.3f} / dev loss: {dev_loss:.3f}'
                  f' / dev EM: {dev_exact:.3f} / dev F1: {dev_f1:.3f}')

            if dev_f1 > max_dev_f1:
                max_dev_f1 = dev_f1
                max_dev_exact = dev_exact
                best_model = copy.deepcopy(model)

            loss = 0
            model.train()

    writer.close()
    print(f'max dev EM: {max_dev_exact:.3f} / max dev F1: {max_dev_f1:.3f}')

    return best_model

# %%
def test(model, ema, args, data):
    device = torch.device(f"cuda:{args['--gpu']}" if torch.cuda.is_available() else "cpu")
    criterion = nn.CrossEntropyLoss()
    loss = 0
    answers = dict()
    model.eval()

    backup_params = EMA(0)
    for name, param in model.named_parameters():
        if param.requires_grad:
            backup_params.register(name, param.data)
            param.data.copy_(ema.get(name))

    with torch.set_grad_enabled(False):
        for batch in iter(data.dev_iter):
            p1, p2 = model(batch)
            batch_loss = criterion(p1, batch.s_idx) + criterion(p2, batch.e_idx)
            loss += batch_loss.item()

            # (batch, c_len, c_len)
            batch_size, c_len = p1.size()
            ls = nn.LogSoftmax(dim=1)
            mask = (torch.ones(c_len, c_len) * float('-inf')).to(device).tril(-1).unsqueeze(0).expand(batch_size, -1, -1)
            score = (ls(p1).unsqueeze(2) + ls(p2).unsqueeze(1)) + mask
            score, s_idx = score.max(dim=1)
            score, e_idx = score.max(dim=1)
            s_idx = torch.gather(s_idx, 1, e_idx.view(-1, 1)).squeeze()

            for i in range(batch_size):
                id = batch.id[i]
                answer = batch.c_word[0][i][s_idx[i]:e_idx[i]+1]
                answer = ' '.join([data.WORD.vocab.itos[idx] for idx in answer])
                answers[id] = answer

        for name, param in model.named_parameters():
            if param.requires_grad:
                param.data.copy_(backup_params.get(name))

    with open(args['prediction_file'], 'w', encoding='utf-8') as f:
        print(json.dumps(answers), file=f)

    results = evaluate_main(args)
    return loss, results['exact_match'], results['f1']

# %%
def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""

    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(prediction_tokens)
    recall = 1.0 * num_same / len(ground_truth_tokens)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)


def evaluate(dataset, predictions):
    f1 = exact_match = total = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if qa['id'] not in predictions:
                    message = 'Unanswered question ' + qa['id'] + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                prediction = predictions[qa['id']]
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total

    return {'exact_match': exact_match, 'f1': f1}


def evaluate_main(args):
    with open(args['dataset_file']) as dataset_file:
        dataset_json = json.load(dataset_file)
        """
        if (dataset_json['version'] != expected_version):
            print('Evaluation expects v-' + expected_version +
                  ', but got dataset with v-' + dataset_json['version'],
                  file=sys.stderr)
        """
        dataset = dataset_json['data']
    with open(args['prediction_file']) as prediction_file:
        predictions = json.load(prediction_file)

    results = evaluate(dataset, predictions)
    #print(json.dumps(results))
    return results


#if __name__ == '__main__':
#    expected_version = '1.1'
#    parser = argparse.ArgumentParser(
#        description='Evaluation for SQuAD ' + expected_version)
#    parser.add_argument('dataset_file', help='Dataset file')
#    parser.add_argument('prediction_file', help='Prediction File')
#    args = parser.parse_args()
#    main(args)

# %%
print('training start!')
best_model = train(args, processed_data)
if not os.path.exists('saved_models'):
        os.makedirs('saved_models')
torch.save(best_model.state_dict(), 'saved_models/BiDAF_'+ args['model_time'] +'.pt')
print('training finished!')
# Out:
# training start!
# epoch: 1
# Streaming output truncated to the last 5000 lines.
# Unanswered question 5ad3bf63604f3c001a3fef5e will receive score 0.
# Unanswered question 5ad3bf63604f3c001a3fef5f will receive score 0.
# Unanswered question 5ad3c46a604f3c001a3fefb1 will receive score 0.
# Unanswered question 5ad3c46a604f3c001a3fefb2 will receive score 0.
# Unanswered question 5ad3c46a604f3c001a3fefb3 will receive score 0.
# Unanswered question 5ad3c46a604f3c001a3fefb4 will receive score 0.
# Unanswered question 5ad3c46a604f3c001a3fefb5 will receive score 0.
# Unanswered question 5ad3cc47604f3c001a3ff143 will receive score 0.
# Unanswered question 5ad3cc47604f3c001a3ff144 will receive score 0.
# Unanswered question 5ad3cc47604f3c001a3ff145 will receive score 0.
# Unanswered question 5ad3cc47604f3c001a3ff146 will receive score 0.
# Unanswered question 5ad21646d7d075001a4283c4 will receive score 0.
# Unanswered question 5ad21646d7d075001a4283c5 will receive score 0.
# Unanswered question 5ad21646d7d075001a4283c6 will receive score 0.
# Unanswered question 5ad21646d7d075001a4283c7 will receive score 0.
# Unanswered question 5ad21e1ad7d075001a42846e will receive score 0.
# Unanswered question 5ad21e1ad7d075001a42846f will receive score 0.
# Unanswered question 5ad21e1ad7d075001a428470 will receive score 0.
# Unanswered question 5ad21e1ad7d075001a428471 will receive score 0.
# Unanswered question 5ad22a95d7d075001a4285da will receive score 0.
# Unanswered question 5ad22a95d7d075001a4285db will receive score 0.
# Unanswered question 5ad22a96d7d075001a4285dc will receive score 0.
# Unanswered question 5ad22a96d7d075001a4285dd will receive score 0.
# Unanswered question 5ad22a96d7d075001a4285de will receive score 0.
# Unanswered question 5ad22cd0d7d075001a428618 will receive score 0.
# Unanswered question 5ad22cd0d7d075001a428619 will receive score 0.
# Unanswered question 5ad22cd0d7d075001a42861a will receive score 0.
# Unanswered question 5ad22cd0d7d075001a42861b will receive score 0.
# Unanswered question 5ad21f6fd7d075001a4284a4 will receive score 0.
# Unanswered question 5ad21f6fd7d075001a4284a5 will receive score 0.
# Unanswered question 5ad21f6fd7d075001a4284a6 will receive score 0.
# Unanswered question 5ad21f6fd7d075001a4284a7 will receive score 0.
# Unanswered question 5ad2678ad7d075001a42922c will receive score 0.
# Unanswered question 5ad2678ad7d075001a42922d will receive score 0.
# Unanswered question 5ad2678ad7d075001a42922e will receive score 0.
# Unanswered question 5ad2678ad7d075001a42922f will receive score 0.
# Unanswered question 5ad2678ad7d075001a429230 will receive score 0.
# Unanswered question 5ad2685dd7d075001a429276 will receive score 0.
# Unanswered question 5ad2685dd7d075001a429278 will receive score 0.
# Unanswered question 5ad2685dd7d075001a429279 will receive score 0.
# Unanswered question 5ad26235d7d075001a429080 will receive score 0.
# Unanswered question 5ad26235d7d075001a429081 will receive score 0.
# Unanswered question 5ad26235d7d075001a429082 will receive score 0.
# Unanswered question 5ad26235d7d075001a429083 will receive score 0.
# Unanswered question 5ad23e1bd7d075001a4288b4 will receive score 0.
# Unanswered question 5ad23e1bd7d075001a4288b5 will receive score 0.
# Unanswered question 5ad23e1bd7d075001a4288b6 will receive score 0.
# Unanswered question 5ad23e1bd7d075001a4288b7 will receive score 0.
# Unanswered question 5ad23e1bd7d075001a4288b8 will receive score 0.
# Unanswered question 5ad22b87d7d075001a428600 will receive score 0.
# Unanswered question 5ad22b87d7d075001a428601 will receive score 0.
# Unanswered question 5ad22b87d7d075001a428602 will receive score 0.
# Unanswered question 5ad22b87d7d075001a428603 will receive score 0.
# Unanswered question 5ad24180d7d075001a428970 will receive score 0.
# Unanswered question 5ad24180d7d075001a428971 will receive score 0.
# Unanswered question 5ad24180d7d075001a428972 will receive score 0.
# Unanswered question 5ad24180d7d075001a428973 will receive score 0.
# Unanswered question 5ad21ebdd7d075001a428488 will receive score 0.
# Unanswered question 5ad21ebdd7d075001a428489 will receive score 0.
# Unanswered question 5ad257e2d7d075001a428d99 will receive score 0.
# Unanswered question 5ad257e2d7d075001a428d9a will receive score 0.
# Unanswered question 5ad2456dd7d075001a428aa2 will receive score 0.
# Unanswered question 5ad2456dd7d075001a428aa3 will receive score 0.
# Unanswered question 5ad2456dd7d075001a428aa4 will receive score 0.
# Unanswered question 5ad258b4d7d075001a428dda will receive score 0.
# Unanswered question 5ad258b4d7d075001a428ddb will receive score 0.
# Unanswered question 5ad258b4d7d075001a428ddc will receive score 0.
# Unanswered question 5ad258b4d7d075001a428ddd will receive score 0.
# Unanswered question 5ad258b4d7d075001a428dde will receive score 0.
# Unanswered question 5ad24eb1d7d075001a428c62 will receive score 0.
# Unanswered question 5ad24eb1d7d075001a428c63 will receive score 0.
# Unanswered question 5ad24eb1d7d075001a428c64 will receive score 0.
# Unanswered question 5ad24eb1d7d075001a428c65 will receive score 0.
# Unanswered question 5ad252e6d7d075001a428d0c will receive score 0.
# Unanswered question 5ad252e6d7d075001a428d0d will receive score 0.
# Unanswered question 5ad252e6d7d075001a428d0e will receive score 0.
# Unanswered question 5ad252e6d7d075001a428d0f will receive score 0.
# Unanswered question 5ad25b1cd7d075001a428e66 will receive score 0.
# Unanswered question 5ad25b1cd7d075001a428e67 will receive score 0.
# Unanswered question 5ad25b1cd7d075001a428e68 will receive score 0.
# Unanswered question 5ad25b1cd7d075001a428e69 will receive score 0.
# Unanswered question 5ad251d6d7d075001a428ce8 will receive score 0.
# Unanswered question 5ad251d6d7d075001a428ce9 will receive score 0.
# Unanswered question 5ad251d6d7d075001a428cea will receive score 0.
# Unanswered question 5ad251d6d7d075001a428ceb will receive score 0.
# Unanswered question 5ad25bf3d7d075001a428e94 will receive score 0.
# Unanswered question 5ad25bf3d7d075001a428e95 will receive score 0.
# Unanswered question 5ad25bf3d7d075001a428e96 will receive score 0.
# Unanswered question 5ad25d05d7d075001a428ed0 will receive score 0.
# Unanswered question 5ad25d05d7d075001a428ed1 will receive score 0.
# Unanswered question 5ad25d05d7d075001a428ed2 will receive score 0.
# Unanswered question 5ad25d05d7d075001a428ed3 will receive score 0.
# Unanswered question 5ad26105d7d075001a428ff4 will receive score 0.
# Unanswered question 5ad26105d7d075001a428ff5 will receive score 0.
# Unanswered question 5ad26105d7d075001a428ff6 will receive score 0.
# Unanswered question 5ad26105d7d075001a428ff7 will receive score 0.
# Unanswered question 5ad25f35d7d075001a428f6a will receive score 0.
# Unanswered question 5ad25f35d7d075001a428f6b will receive score 0.
# Unanswered question 5ad25f35d7d075001a428f6c will receive score 0.
# Unanswered question 5ad25f35d7d075001a428f6d will receive score 0.
# Unanswered question 5ad25e70d7d075001a428f1c will receive score 0.
# Unanswered question 5ad25e70d7d075001a428f1d will receive score 0.
# Unanswered question 5ad25e70d7d075001a428f1e will receive score 0.
# Unanswered question 5ad25e70d7d075001a428f1f will receive score 0.
# Unanswered question 5ad261bad7d075001a429050 will receive score 0.
# Unanswered question 5ad261bad7d075001a429051 will receive score 0.
# Unanswered question 5ad3bc28604f3c001a3feee2 will receive score 0.
# Unanswered question 5ad3bc28604f3c001a3feee3 will receive score 0.
# Unanswered question 5ad3bce5604f3c001a3feefb will receive score 0.
# Unanswered question 5ad3bce5604f3c001a3feefc will receive score 0.
# Unanswered question 5ad3bce5604f3c001a3feefd will receive score 0.
# Unanswered question 5ad3bce5604f3c001a3feefe will receive score 0.
# Unanswered question 5ad3bce5604f3c001a3feeff will receive score 0.
# Unanswered question 5ad3bd30604f3c001a3fef0f will receive score 0.
# Unanswered question 5ad3bd30604f3c001a3fef10 will receive score 0.
# Unanswered question 5ad3bd30604f3c001a3fef11 will receive score 0.
# Unanswered question 5ad3bd30604f3c001a3fef12 will receive score 0.
# Unanswered question 5ad3bd30604f3c001a3fef13 will receive score 0.
# Unanswered question 5ad3bd87604f3c001a3fef23 will receive score 0.
# Unanswered question 5ad3bd87604f3c001a3fef24 will receive score 0.
# Unanswered question 5ad3bd87604f3c001a3fef25 will receive score 0.
# Unanswered question 5ad3bd87604f3c001a3fef26 will receive score 0.
# Unanswered question 5ad3bd87604f3c001a3fef27 will receive score 0.
# Unanswered question 5ad25efad7d075001a428f56 will receive score 0.
# Unanswered question 5ad25efad7d075001a428f57 will receive score 0.
# Unanswered question 5ad25efad7d075001a428f58 will receive score 0.
# Unanswered question 5ad25efad7d075001a428f59 will receive score 0.
# Unanswered question 5ad25efad7d075001a428f5a will receive score 0.
# Unanswered question 5ad25f82d7d075001a428f84 will receive score 0.
# Unanswered question 5ad25f82d7d075001a428f85 will receive score 0.
# Unanswered question 5ad25f82d7d075001a428f86 will receive score 0.
# Unanswered question 5ad25f82d7d075001a428f87 will receive score 0.
# Unanswered question 5ad2605dd7d075001a428fc6 will receive score 0.
# Unanswered question 5ad2605dd7d075001a428fc7 will receive score 0.
# Unanswered question 5ad2605dd7d075001a428fc8 will receive score 0.
# Unanswered question 5ad2605dd7d075001a428fc9 will receive score 0.
# Unanswered question 5ad26103d7d075001a428fec will receive score 0.
# Unanswered question 5ad26103d7d075001a428fed will receive score 0.
# Unanswered question 5ad26103d7d075001a428fee will receive score 0.
# Unanswered question 5ad26103d7d075001a428fef will receive score 0.
# Unanswered question 5ad261a4d7d075001a429048 will receive score 0.
# Unanswered question 5ad261a4d7d075001a429049 will receive score 0.
# Unanswered question 5ad261a4d7d075001a42904a will receive score 0.
# Unanswered question 5ad261a4d7d075001a42904b will receive score 0.
# Unanswered question 5ad26257d7d075001a42909c will receive score 0.
# Unanswered question 5ad26257d7d075001a42909d will receive score 0.
# Unanswered question 5ad26257d7d075001a42909e will receive score 0.
# Unanswered question 5ad26257d7d075001a42909f will receive score 0.
# Unanswered question 5ad262f7d7d075001a4290d4 will receive score 0.
# Unanswered question 5ad262f7d7d075001a4290d5 will receive score 0.
# Unanswered question 5ad262f7d7d075001a4290d6 will receive score 0.
# Unanswered question 5ad262f7d7d075001a4290d7 will receive score 0.
# Unanswered question 5ad26382d7d075001a42911a will receive score 0.
# Unanswered question 5ad26382d7d075001a42911b will receive score 0.
# Unanswered question 5ad26382d7d075001a42911c will receive score 0.
# Unanswered question 5ad26382d7d075001a42911d will receive score 0.
# Unanswered question 5ad26421d7d075001a42913e will receive score 0.
# Unanswered question 5ad26421d7d075001a42913f will receive score 0.
# Unanswered question 5ad26421d7d075001a429140 will receive score 0.
# Unanswered question 5ad266f6d7d075001a4291fe will receive score 0.
# Unanswered question 5ad266f6d7d075001a4291ff will receive score 0.
# Unanswered question 5ad266f6d7d075001a429200 will receive score 0.
# Unanswered question 5ad266f6d7d075001a429201 will receive score 0.
# Unanswered question 5ad26797d7d075001a429236 will receive score 0.
# Unanswered question 5ad26797d7d075001a429237 will receive score 0.
# Unanswered question 5ad26797d7d075001a429238 will receive score 0.
# Unanswered question 5ad26797d7d075001a429239 will receive score 0.
# Unanswered question 5ad26839d7d075001a42925a will receive score 0.
# Unanswered question 5ad26839d7d075001a42925b will receive score 0.
# Unanswered question 5ad26839d7d075001a42925c will receive score 0.
# Unanswered question 5ad26839d7d075001a42925d will receive score 0.
# Unanswered question 5ad26925d7d075001a4292c4 will receive score 0.
# Unanswered question 5ad26925d7d075001a4292c5 will receive score 0.
# Unanswered question 5ad26925d7d075001a4292c6 will receive score 0.
# Unanswered question 5ad26925d7d075001a4292c7 will receive score 0.
# Unanswered question 5ad269a7d7d075001a4292e0 will receive score 0.
# Unanswered question 5ad269a7d7d075001a4292e1 will receive score 0.
# Unanswered question 5ad269a7d7d075001a4292e2 will receive score 0.
# Unanswered question 5ad269a7d7d075001a4292e3 will receive score 0.
# Unanswered question 5ad26a5fd7d075001a429318 will receive score 0.
# Unanswered question 5ad26a5fd7d075001a429319 will receive score 0.
# Unanswered question 5ad26a5fd7d075001a42931a will receive score 0.
# Unanswered question 5ad26a5fd7d075001a42931b will receive score 0.
# Unanswered question 5ad26aedd7d075001a429332 will receive score 0.
# Unanswered question 5ad26aedd7d075001a429333 will receive score 0.
# Unanswered question 5ad26aedd7d075001a429334 will receive score 0.
# Unanswered question 5ad26aedd7d075001a429335 will receive score 0.
# Unanswered question 5ad26c15d7d075001a42937c will receive score 0.
# Unanswered question 5ad26c15d7d075001a42937d will receive score 0.
# Unanswered question 5ad26c15d7d075001a42937e will receive score 0.
# Unanswered question 5ad26c15d7d075001a42937f will receive score 0.
# Unanswered question 5ad27697d7d075001a429518 will receive score 0.
# Unanswered question 5ad27697d7d075001a429519 will receive score 0.
# Unanswered question 5ad27697d7d075001a42951a will receive score 0.
# Unanswered question 5ad27697d7d075001a42951b will receive score 0.
# Unanswered question 5ad2772cd7d075001a42953e will receive score 0.
# Unanswered question 5ad2772cd7d075001a42953f will receive score 0.
# Unanswered question 5ad2772cd7d075001a429540 will receive score 0.
# Unanswered question 5ad2772cd7d075001a429541 will receive score 0.
# Unanswered question 5ad277d3d7d075001a429546 will receive score 0.
# Unanswered question 5ad277d3d7d075001a429547 will receive score 0.
# Unanswered question 5ad277d3d7d075001a429548 will receive score 0.
# Unanswered question 5ad277d3d7d075001a429549 will receive score 0.
# Unanswered question 5ad278c3d7d075001a42957c will receive score 0.
# Unanswered question 5ad278c3d7d075001a42957d will receive score 0.
# Unanswered question 5ad278c3d7d075001a42957e will receive score 0.
# Unanswered question 5ad278c3d7d075001a42957f will receive score 0.
# Unanswered question 5ad27941d7d075001a4295a8 will receive score 0.
# Unanswered question 5ad27941d7d075001a4295a9 will receive score 0.
# Unanswered question 5ad27941d7d075001a4295aa will receive score 0.
# Unanswered question 5ad27941d7d075001a4295ab will receive score 0.
# Unanswered question 5ad279e5d7d075001a4295c2 will receive score 0.
# Unanswered question 5ad279e5d7d075001a4295c3 will receive score 0.
# Unanswered question 5ad279e5d7d075001a4295c4 will receive score 0.
# Unanswered question 5ad279e5d7d075001a4295c5 will receive score 0.
# Unanswered question 5ad27a80d7d075001a4295fa will receive score 0.
# Unanswered question 5ad27a80d7d075001a4295fb will receive score 0.
# Unanswered question 5ad27a80d7d075001a4295fc will receive score 0.
# Unanswered question 5ad27a80d7d075001a4295fd will receive score 0.
# Unanswered question 5ad27e30d7d075001a429700 will receive score 0.
# Unanswered question 5ad27e30d7d075001a429701 will receive score 0.
# Unanswered question 5ad27e30d7d075001a429702 will receive score 0.
# Unanswered question 5ad27e30d7d075001a429703 will receive score 0.
# Unanswered question 5ad27f01d7d075001a429742 will receive score 0.
# Unanswered question 5ad27f01d7d075001a429743 will receive score 0.
# Unanswered question 5ad27f01d7d075001a429744 will receive score 0.
# Unanswered question 5ad27f01d7d075001a429745 will receive score 0.
# Unanswered question 5ad27fb9d7d075001a429782 will receive score 0.
# Unanswered question 5ad27fb9d7d075001a429783 will receive score 0.
# Unanswered question 5ad27fb9d7d075001a429784 will receive score 0.
# Unanswered question 5ad27fb9d7d075001a429785 will receive score 0.
# Unanswered question 5ad28035d7d075001a4297a6 will receive score 0.
# Unanswered question 5ad28035d7d075001a4297a7 will receive score 0.
# Unanswered question 5ad28035d7d075001a4297a8 will receive score 0.
# Unanswered question 5ad28035d7d075001a4297a9 will receive score 0.
# Unanswered question 5ad280d4d7d075001a4297d6 will receive score 0.
# Unanswered question 5ad280d4d7d075001a4297d7 will receive score 0.
# Unanswered question 5ad280d4d7d075001a4297d8 will receive score 0.
# Unanswered question 5ad280d4d7d075001a4297d9 will receive score 0.
# Unanswered question 5ad28173d7d075001a4297fa will receive score 0.
# Unanswered question 5ad28173d7d075001a4297fb will receive score 0.
# Unanswered question 5ad28173d7d075001a4297fc will receive score 0.
# Unanswered question 5ad28173d7d075001a4297fd will receive score 0.
# Unanswered question 5ad28237d7d075001a429820 will receive score 0.
# Unanswered question 5ad28237d7d075001a429821 will receive score 0.
# Unanswered question 5ad28237d7d075001a429822 will receive score 0.
# Unanswered question 5ad28237d7d075001a429823 will receive score 0.
# Unanswered question 5ad283bcd7d075001a42985a will receive score 0.
# Unanswered question 5ad283bcd7d075001a42985b will receive score 0.
# Unanswered question 5ad283bcd7d075001a42985c will receive score 0.
# Unanswered question 5ad283bcd7d075001a42985d will receive score 0.
# Unanswered question 5ad28471d7d075001a429876 will receive score 0.
# Unanswered question 5ad28471d7d075001a429877 will receive score 0.
# Unanswered question 5ad28471d7d075001a429878 will receive score 0.
# Unanswered question 5ad28471d7d075001a429879 will receive score 0.
# Unanswered question 5ad28597d7d075001a4298ae will receive score 0.
# Unanswered question 5ad28597d7d075001a4298af will receive score 0.
# Unanswered question 5ad28597d7d075001a4298b0 will receive score 0.
# Unanswered question 5ad28597d7d075001a4298b1 will receive score 0.
# Unanswered question 5ad28614d7d075001a4298c0 will receive score 0.
# Unanswered question 5ad28614d7d075001a4298c1 will receive score 0.
# Unanswered question 5ad28614d7d075001a4298c2 will receive score 0.
# Unanswered question 5ad28614d7d075001a4298c3 will receive score 0.
# Unanswered question 5ad2866ed7d075001a4298e6 will receive score 0.
# Unanswered question 5ad2866ed7d075001a4298e7 will receive score 0.
# Unanswered question 5ad2866ed7d075001a4298e8 will receive score 0.
# Unanswered question 5ad286fdd7d075001a429900 will receive score 0.
# Unanswered question 5ad286fdd7d075001a429901 will receive score 0.
# Unanswered question 5ad286fdd7d075001a429902 will receive score 0.
# Unanswered question 5ad286fdd7d075001a429903 will receive score 0.
# Unanswered question 5ad2877cd7d075001a429912 will receive score 0.
# Unanswered question 5ad2877cd7d075001a429913 will receive score 0.
# Unanswered question 5ad2877cd7d075001a429914 will receive score 0.
# Unanswered question 5ad2877cd7d075001a429915 will receive score 0.
# Unanswered question 5ad28846d7d075001a42992e will receive score 0.
# Unanswered question 5ad28846d7d075001a42992f will receive score 0.
# Unanswered question 5ad28846d7d075001a429930 will receive score 0.
# Unanswered question 5ad28846d7d075001a429931 will receive score 0.
# Unanswered question 5ad288e1d7d075001a429970 will receive score 0.
# Unanswered question 5ad288e1d7d075001a429971 will receive score 0.
# Unanswered question 5ad288e1d7d075001a429972 will receive score 0.
# Unanswered question 5ad288e1d7d075001a429973 will receive score 0.
# Unanswered question 5ad2895bd7d075001a429982 will receive score 0.
# Unanswered question 5ad2895bd7d075001a429983 will receive score 0.
# Unanswered question 5ad2895bd7d075001a429984 will receive score 0.
# Unanswered question 5ad2895bd7d075001a429985 will receive score 0.
# Unanswered question 5ad289c2d7d075001a42999e will receive score 0.
# Unanswered question 5ad289c2d7d075001a42999f will receive score 0.
# Unanswered question 5ad289c2d7d075001a4299a0 will receive score 0.
# Unanswered question 5ad289c2d7d075001a4299a1 will receive score 0.
# Unanswered question 5ad28a57d7d075001a4299b0 will receive score 0.
# Unanswered question 5ad28a57d7d075001a4299b1 will receive score 0.
# Unanswered question 5ad28a57d7d075001a4299b2 will receive score 0.
# Unanswered question 5ad28a57d7d075001a4299b3 will receive score 0.
# Unanswered question 5ad28ad0d7d075001a4299cc will receive score 0.
# Unanswered question 5ad28ad0d7d075001a4299cd will receive score 0.
# Unanswered question 5ad28ad0d7d075001a4299ce will receive score 0.
# Unanswered question 5ad28ad0d7d075001a4299cf will receive score 0.
# train loss: 1013.635 / dev loss: 1110.471 / dev EM: 15.885 / dev F1: 22.767
